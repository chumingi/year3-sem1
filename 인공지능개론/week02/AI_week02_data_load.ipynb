# %% [markdown]
# # 데이터 로드 실습
# 1. csv 데이터를 파일에서 가져오기
# 2. csv 데이터를 웹에서 가져오기
# 3. xlsx 데이터를 파일에서 가져오기
# 4. xlsx 데이터를 웹에서 가져오기

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# 1. csv 데이터를 파일에서 가져오기
file_path = r"C:\Users\MinGi\Desktop\year3-sem1\인공지능개론\dataset\mobile.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# 2. csv 데이터를 웹에서 가져오기
url = "https://raw.githubusercontent.com/MyungKyuYi/AI-class/main/mobile.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# 3. xlsx 데이터를 파일에서 가져오기
file_path = r"C:\Users\MinGi\Desktop\year3-sem1\인공지능개론\dataset\combined_dataset-1.xlsx"
df = pd.read_excel(file_path, engine="openpyxl")

df.head()
# Out:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     1           2   Female         45         152          63
# 2     1           2   Female         45         152          63
# 3     2           3   Female         50         157          50
# 4     2           3   Female         50         157          50
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            161                              89
# 2                            161                              89
# 3                            160                              93
# 4                            160                              93
#
#    Heart Rate(b/m)  BMI(kg/m^2)  ...  2091  2092  2093  2094  2095  2096  \
# 0               97    27.268006  ...  1766  1766  1766  1833  1833  1827
# ...

# %%
# 4. xlsx 데이터를 웹에서 가져오기
url = "https://raw.githubusercontent.com/MyungKyuYi/AI-class/main/combined_dataset-1.xlsx"
df = pd.read_excel(url, engine="openpyxl")

df.head()
# Out:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     1           2   Female         45         152          63
# 2     1           2   Female         45         152          63
# 3     2           3   Female         50         157          50
# 4     2           3   Female         50         157          50
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            161                              89
# 2                            161                              89
# 3                            160                              93
# 4                            160                              93
#
#    Heart Rate(b/m)  BMI(kg/m^2)  ...  2091  2092  2093  2094  2095  2096  \
# 0               97    27.268006  ...  1766  1766  1766  1833  1833  1827
# ...
